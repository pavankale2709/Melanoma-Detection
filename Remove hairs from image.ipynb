# %%
# https://www.kaggle.com/code/vatsalparsaniya/melanoma-hair-remove

import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
from glob import glob

# %%
data_dir_train = 'Train'

# %%
path_list_train = [x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
lesion_list_train = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
image_list_train = [os.path.basename(y) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]

# %%
dict = {}
dict['image_names'] = image_list_train
dict['folder'] = lesion_list_train
dict['image_path'] = path_list_train
df_train = pd.DataFrame(dict)
df_train.head()
# Out:
#         image_names             folder  \
# 0  ISIC_0025780.jpg  actinic keratosis
# 1  ISIC_0025803.jpg  actinic keratosis
# 2  ISIC_0025825.jpg  actinic keratosis
# 3  ISIC_0025953.jpg  actinic keratosis
# 4  ISIC_0025957.jpg  actinic keratosis
#
#                                  image_path
# 0  Train\actinic keratosis\ISIC_0025780.jpg
# 1  Train\actinic keratosis\ISIC_0025803.jpg
# 2  Train\actinic keratosis\ISIC_0025825.jpg
# 3  Train\actinic keratosis\ISIC_0025953.jpg
# 4  Train\actinic keratosis\ISIC_0025957.jpg

# %%
for ind in df_train.index:
    print("Working on image: " + df_train['image_path'][ind])
    image = cv2.imread(df_train['image_path'][ind])
    dim = (img.shape[1], img.shape[0])
    image_resize = cv2.resize(image, dim)

    grayScale = cv2.cvtColor(image_resize, cv2.COLOR_RGB2GRAY)
    
    # Kernel for the morphological filtering
    kernel = cv2.getStructuringElement(1,(17,17))
    
    # Perform the blackHat filtering on the grayscale image to find the hair countours
    blackhat = cv2.morphologyEx(grayScale, cv2.MORPH_BLACKHAT, kernel)
    
    # intensify the hair countours in preparation for the inpainting 
    ret,threshold = cv2.threshold(blackhat,10,255,cv2.THRESH_BINARY)
    
    # inpaint the original image depending on the mask
    final_image = cv2.inpaint(image_resize,threshold,1,cv2.INPAINT_TELEA)
    
    #Save converted image
    imageName = "C:\\Users\\pakale\\Desktop\\Upgrad - E_PG AI and ML\\Notes\\5. Deep Learning\\Melanoma Detection Assignment\\train_result\\" + df_train['folder'][ind] + "\\" + df_train['image_names'][ind]
    result = cv2.imwrite(imageName, final_image)
    print("result: " + str(result))
    print("Generated image: " + imageName)
# Out:
# Working on image: Train\actinic keratosis\ISIC_0025780.jpg
# result: True
# Generated image: C:\Users\pakale\Desktop\Upgrad - E_PG AI and ML\Notes\5. Deep Learning\Melanoma Detection Assignment\train_result\actinic keratosis\ISIC_0025780.jpg
# Working on image: Train\actinic keratosis\ISIC_0025803.jpg
# result: True
# Generated image: C:\Users\pakale\Desktop\Upgrad - E_PG AI and ML\Notes\5. Deep Learning\Melanoma Detection Assignment\train_result\actinic keratosis\ISIC_0025803.jpg
# Working on image: Train\actinic keratosis\ISIC_0025825.jpg
# result: True
# Generated image: C:\Users\pakale\Desktop\Upgrad - E_PG AI and ML\Notes\5. Deep Learning\Melanoma Detection Assignment\train_result\actinic keratosis\ISIC_0025825.jpg
# Working on image: Train\actinic keratosis\ISIC_0025953.jpg
# result: True
# Generated image: C:\Users\pakale\Desktop\Upgrad - E_PG AI and ML\Notes\5. Deep Learning\Melanoma Detection Assignment\train_result\actinic keratosis\ISIC_0025953.jpg
# ...
